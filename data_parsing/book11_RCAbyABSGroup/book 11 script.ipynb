# %%
# !sudo apt-get update
# !sudo apt-get install -y poppler-utils tesseract-ocr
# !tesseract --version # Verify tesseract install
# !pip install -U "unstructured[ocr, local-inference]" pymupdf pytesseract pdfminer.six pi-heif
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,863 kB]
# Get:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,700 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Fetched 18.3 MB in 8s (2,185 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.7 [186 kB]
# Fetched 186 kB in 1s (141 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126333 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.7_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.7) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.7) ...
# Processing triggers for man-db (2.10.2-1) ...
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8
# Collecting pymupdf
#   Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Collecting pdfminer.six
#   Downloading pdfminer_six-20250416-py3-none-any.whl.metadata (4.1 kB)
# Collecting pi-heif
#   Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting unstructured[local-inference,ocr]
#   Downloading unstructured-0.17.2-py3-none-any.whl.metadata (24 kB)
# WARNING: unstructured 0.17.2 does not provide the extra 'ocr'
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (5.2.0)
# Collecting filetype (from unstructured[local-inference,ocr])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured[local-inference,ocr])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (5.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (4.13.4)
# Collecting emoji (from unstructured[local-inference,ocr])
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured[local-inference,ocr])
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured[local-inference,ocr])
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured[local-inference,ocr])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 15.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (2.0.2)
# Collecting rapidfuzz (from unstructured[local-inference,ocr])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured[local-inference,ocr])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (4.13.2)
# Collecting unstructured-client (from unstructured[local-inference,ocr])
#   Downloading unstructured_client-0.34.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (1.17.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (5.9.5)
# Collecting python-oxmsg (from unstructured[local-inference,ocr])
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (1.1)
# Collecting onnxruntime>=1.19.0 (from unstructured[local-inference,ocr])
#   Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting python-pptx>=1.0.1 (from unstructured[local-inference,ocr])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting effdet (from unstructured[local-inference,ocr])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting pypandoc (from unstructured[local-inference,ocr])
#   Downloading pypandoc-1.15-py3-none-any.whl.metadata (16 kB)
# Collecting pikepdf (from unstructured[local-inference,ocr])
#   Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting google-cloud-vision (from unstructured[local-inference,ocr])
#   Downloading google_cloud_vision-3.10.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[local-inference,ocr])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Collecting unstructured-inference>=0.8.10 (from unstructured[local-inference,ocr])
#   Downloading unstructured_inference-0.8.10-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (2.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (3.4.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (2.2.2)
# Collecting pdf2image (from unstructured[local-inference,ocr])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (3.1.5)
# Collecting python-docx>=1.1.2 (from unstructured[local-inference,ocr])
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting pypdf (from unstructured[local-inference,ocr])
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting onnx>=1.17.0 (from unstructured[local-inference,ocr])
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from unstructured[local-inference,ocr]) (3.8)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.17.0->unstructured[local-inference,ocr]) (5.29.4)
# Collecting coloredlogs (from onnxruntime>=1.19.0->unstructured[local-inference,ocr])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.19.0->unstructured[local-inference,ocr]) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.19.0->unstructured[local-inference,ocr]) (1.13.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=1.0.1->unstructured[local-inference,ocr])
#   Downloading XlsxWriter-3.2.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting python-multipart (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (0.30.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (2.6.0+cu124)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (1.0.15)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (4.51.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (1.14.1)
# Collecting pypdfium2 (from unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->unstructured[local-inference,ocr]) (2.7)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[local-inference,ocr])
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured[local-inference,ocr])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[local-inference,ocr]) (0.21.0+cu124)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[local-inference,ocr]) (2.0.8)
# Collecting omegaconf>=2.0 (from effdet->unstructured[local-inference,ocr])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference,ocr]) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-vision->unstructured[local-inference,ocr]) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-vision->unstructured[local-inference,ocr]) (1.26.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib->unstructured[local-inference,ocr]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib->unstructured[local-inference,ocr]) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[local-inference,ocr]) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[local-inference,ocr]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[local-inference,ocr]) (2024.11.6)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl->unstructured[local-inference,ocr]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->unstructured[local-inference,ocr]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->unstructured[local-inference,ocr]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->unstructured[local-inference,ocr]) (2025.2)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pikepdf->unstructured[local-inference,ocr]) (1.2.18)
# Collecting olefile (from python-oxmsg->unstructured[local-inference,ocr])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[local-inference,ocr]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[local-inference,ocr]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[local-inference,ocr]) (2025.1.31)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured[local-inference,ocr])
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting eval-type-backport>=0.2.0 (from unstructured-client->unstructured[local-inference,ocr])
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[local-inference,ocr]) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[local-inference,ocr]) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[local-inference,ocr]) (2.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[local-inference,ocr]) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[local-inference,ocr]) (0.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference,ocr]) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference,ocr]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference,ocr]) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference,ocr]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference,ocr]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference,ocr]) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference,ocr]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference,ocr]) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[local-inference,ocr]) (0.14.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[local-inference,ocr])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.0->effdet->unstructured[local-inference,ocr]) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[local-inference,ocr]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[local-inference,ocr]) (2.33.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.18.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.19.0->unstructured[local-inference,ocr]) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (0.21.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[local-inference,ocr])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.19.0->unstructured[local-inference,ocr])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference,ocr]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[local-inference,ocr]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->unstructured-inference>=0.8.10->unstructured[local-inference,ocr]) (3.0.2)
# Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 85.6 MB/s eta 0:00:00
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Downloading pdfminer_six-20250416-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 101.5 MB/s eta 0:00:00
# Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.9 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 84.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 88.7 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 18.2 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 30.8 MB/s eta 0:00:00
# Downloading unstructured_inference-0.8.10-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.3 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 9.7 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 38.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.10.1-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.1/526.1 kB 34.5 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 80.4 MB/s eta 0:00:00
# Downloading pypandoc-1.15-py3-none-any.whl (21 kB)
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 22.1 MB/s eta 0:00:00
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 14.1 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 92.5 MB/s eta 0:00:00
# Downloading unstructured-0.17.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.3 MB/s eta 0:00:00
# Downloading unstructured_client-0.34.0-py3-none-any.whl (189 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.4/189.4 kB 15.1 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading XlsxWriter-3.2.3-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 15.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 10.8 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 85.8 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: langdetect, antlr4-python3-runtime
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=80649478906b2bfb0c990e21dff3319dd625993be239842499570829c1f68e37
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=d6238ae495856cf188815883b2e89ce18fe24065050abae5bc91f49b5eddb0b8
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built langdetect antlr4-python3-runtime
# Installing collected packages: filetype, antlr4-python3-runtime, XlsxWriter, unstructured.pytesseract, rapidfuzz, python-multipart, python-magic, python-iso639, python-docx, pytesseract, pypdfium2, pypdf, pypandoc, pymupdf, pi-heif, pdf2image, onnx, omegaconf, olefile, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, langdetect, humanfriendly, eval-type-backport, emoji, backoff, aiofiles, typing-inspect, python-pptx, python-oxmsg, pikepdf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, unstructured-client, pdfminer.six, onnxruntime, nvidia-cusolver-cu12, dataclasses-json, unstructured, google-cloud-vision, unstructured-inference, effdet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed XlsxWriter-3.2.3 aiofiles-24.1.0 antlr4-python3-runtime-4.9.3 backoff-2.2.1 coloredlogs-15.0.1 dataclasses-json-0.6.7 effdet-0.4.1 emoji-2.14.1 eval-type-backport-0.2.2 filetype-1.2.0 google-cloud-vision-3.10.1 humanfriendly-10.0 langdetect-1.0.9 marshmallow-3.26.1 mypy-extensions-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 olefile-0.47 omegaconf-2.3.0 onnx-1.17.0 onnxruntime-1.21.1 pdf2image-1.17.0 pdfminer.six-20250416 pi-heif-0.22.0 pikepdf-9.7.0 pymupdf-1.25.5 pypandoc-1.15 pypdf-5.4.0 pypdfium2-4.30.1 pytesseract-0.3.13 python-docx-1.1.2 python-iso639-2025.2.18 python-magic-0.4.27 python-multipart-0.0.20 python-oxmsg-0.0.2 python-pptx-1.0.2 rapidfuzz-3.13.0 typing-inspect-0.9.0 unstructured-0.17.2 unstructured-client-0.34.0 unstructured-inference-0.8.10 unstructured.pytesseract-0.3.15

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pdf_path = "/content/drive/MyDrive/RCA_ABSgroup.pdf"

# %%
# !sudo apt-get update
# !sudo apt-get install -y poppler-utils
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.7).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import os
import json
import re
import fitz  # Optional: For validation or page count
from unstructured.partition.pdf import partition_pdf

# --- Configuration ---
PDF_PATH = pdf_path # Your PDF path
OUTPUT_BASE_DIR = "output_grouped_text_chunk" # Changed dir name
OUTPUT_JSON_DIR = os.path.join(OUTPUT_BASE_DIR, "data")

# --- Define Start and End Markers ---
# The exact heading text (after cleaning) that starts a new block
START_MARKER_HEADING = "Typical Issues"
# A specific text string that reliably ends the block to be collected
# Using 'in' operator for matching, so partial match is okay if needed
END_MARKER_TEXT = "Primary Difficulty SOURCE" # Check exact text from PDF/OCR
# List of intermediate headings *not* to include in the final text_chunk
INTERMEDIATE_HEADINGS_TO_SKIP = [
    "Typical Issues", # Also skip the start marker itself
    "Typical Recommendations",
    "Examples"
]

# --- Helper Functions ---

def clean_text_for_final_chunk(text):
    """Cleans text for final concatenation. Removes page numbers, excessive whitespace."""
    if not text: return ""
    # Remove lines that are only digits or whitespace
    lines = text.split('\n')
    cleaned_lines = []
    for line in lines:
        if re.fullmatch(r'\s*\d+\s*', line.strip()):
            continue
        # Normalize spaces within the line
        cleaned_line = re.sub(r'\s+', ' ', line).strip()
        if cleaned_line: # Only keep non-empty lines
            cleaned_lines.append(cleaned_line)
    # Join cleaned lines with a single space for the final text chunk
    return " ".join(cleaned_lines)

def get_base_filename(filepath):
    """Extracts filename without extension."""
    return os.path.splitext(os.path.basename(filepath))[0]

# --- Main Processing Logic ---

print(f"--- Starting Grouped Text Chunk Processing ---")
print(f"PDF: {PDF_PATH}")
print(f"Output Base Directory: {OUTPUT_BASE_DIR}")

if not os.path.exists(PDF_PATH):
    print(f"\nERROR: PDF File not found at '{PDF_PATH}'")
    exit()
else:
    print(f"Found PDF file. Size: {os.path.getsize(PDF_PATH)} bytes.")

os.makedirs(OUTPUT_JSON_DIR, exist_ok=True)
filename_base = get_base_filename(PDF_PATH)

print(f"\n--- Starting Text Partitioning (using OCR) ---")
final_topic_objects = [] # Final list of topic objects
current_topic_content_lines = [] # Accumulates lines for the current topic
current_topic_start_page = None
processing_active_topic = False # Flag to indicate if we are between start and end markers

try:
    elements = partition_pdf(filename=PDF_PATH, strategy="ocr_only")
    print(f"Text partitioning complete (using OCR). Found {len(elements)} elements.")
    if not elements: print("WARNING: No elements were extracted via OCR.")

    print(f"\n--- Processing Elements and Grouping Text Chunks ---")

    for elem_idx, element in enumerate(elements):
        element_category = element.category
        metadata = element.metadata.to_dict()
        page_number = metadata.get('page_number', None)
        element_original_text = element.text

        # Skip common noise elements explicitly
        if element_category in ["Header", "Footer", "PageNumber", "Image", "Figure", "FigureCaption"]:
            continue

        # Clean the text for processing and matching
        cleaned_element_text = clean_text_for_final_chunk(element_original_text)

        # Skip if element is empty after cleaning
        if not cleaned_element_text:
            continue

        # --- Check for START Marker ---
        if cleaned_element_text == START_MARKER_HEADING:
            # If we were processing a previous topic, finalize it
            if processing_active_topic:
                final_text_chunk = " ".join(current_topic_content_lines)
                if final_text_chunk: # Only add if content was collected
                     topic_object = {
                         "source_document": os.path.basename(PDF_PATH),
                         "start_page": current_topic_start_page,
                         "text_chunk": final_text_chunk
                     }
                     final_topic_objects.append(topic_object)
                     print(f"DEBUG: Finalized topic starting on page {current_topic_start_page}")

            # Start collecting for a new topic
            print(f"DEBUG: Found START marker '{START_MARKER_HEADING}' on page {page_number}. Starting new topic.")
            current_topic_content_lines = [] # Reset content accumulator
            current_topic_start_page = page_number
            processing_active_topic = True
            # Don't add the heading itself to the content
            continue # Move to next element

        # --- Check for END Marker ---
        # Use 'in' for robustness against minor OCR variations or surrounding text
        if END_MARKER_TEXT in cleaned_element_text:
            # If we are currently processing a topic, finalize it
            if processing_active_topic:
                print(f"DEBUG: Found END marker containing '{END_MARKER_TEXT}' on page {page_number}. Finalizing current topic.")
                final_text_chunk = " ".join(current_topic_content_lines)
                if final_text_chunk: # Only add if content was collected
                    topic_object = {
                        "source_document": os.path.basename(PDF_PATH),
                        "start_page": current_topic_start_page,
                        "text_chunk": final_text_chunk
                    }
                    final_topic_objects.append(topic_object)

                # Reset state: stop processing until the next START marker
                processing_active_topic = False
                current_topic_content_lines = []
                current_topic_start_page = None
            # Don't add the end marker text itself
            continue # Move to next element

        # --- Check for Intermediate Headings to Skip ---
        is_intermediate_heading = cleaned_element_text in INTERMEDIATE_HEADINGS_TO_SKIP
        if is_intermediate_heading and processing_active_topic:
            # Skip adding these specific headings to the text chunk
            print(f"DEBUG: Skipping intermediate heading '{cleaned_element_text}' on page {page_number}")
            continue # Move to next element

        # --- Accumulate Content if inside an active topic ---
        if processing_active_topic:
            # Append the cleaned text (representing the content of this element)
            current_topic_content_lines.append(cleaned_element_text)


    # --- Final Step: Add the last topic if file ended mid-topic ---
    if processing_active_topic and current_topic_content_lines:
        print(f"DEBUG: Reached end of PDF while processing topic starting on page {current_topic_start_page}. Finalizing.")
        final_text_chunk = " ".join(current_topic_content_lines)
        topic_object = {
            "source_document": os.path.basename(PDF_PATH),
            "start_page": current_topic_start_page,
            "text_chunk": final_text_chunk
        }
        final_topic_objects.append(topic_object)

    print(f"\nProcessing complete.")
    print(f"Generated {len(final_topic_objects)} grouped text chunk objects.")

    # --- Save the Final Structured Data ---
    output_filename = os.path.join(OUTPUT_JSON_DIR, f"{filename_base}_grouped_text_chunks.json")
    # Ensure UTF-8 encoding when writing
    with open(output_filename, 'w', encoding='utf-8') as f:
        json.dump(final_topic_objects, f, indent=2, ensure_ascii=False)

    print(f"\n--- Output ---")
    print(f"Grouped text chunk data saved to: {output_filename}")
    print(f"\n--- Note ---")
    print("Each object in the JSON groups text from 'Typical Issues' until 'Primary Difficulty SOURCE'.")
    print("Includes only 'source_document', 'start_page', and 'text_chunk' keys.")
    print("This format is for specific structured viewing/processing.")

except ImportError as e:
     print(f"\nERROR: Import failed. Ensure all libraries and system dependencies are installed. {e}")
except Exception as e:
    print(f"\nAn error occurred during processing: {e}")
    import traceback
    traceback.print_exc()
# Out:
# --- Starting Grouped Text Chunk Processing ---
# PDF: /content/drive/MyDrive/RCA_ABSgroup.pdf
# Output Base Directory: output_grouped_text_chunk
# Found PDF file. Size: 66191092 bytes.
#
# --- Starting Text Partitioning (using OCR) ---
# Text partitioning complete (using OCR). Found 4267 elements.
#
# --- Processing Elements and Grouping Text Chunks ---
# DEBUG: Found START marker 'Typical Issues' on page 1. Starting new topic.
# DEBUG: Finalized topic starting on page 1
# DEBUG: Found START marker 'Typical Issues' on page 2. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 2
# DEBUG: Finalized topic starting on page 2
# DEBUG: Found START marker 'Typical Issues' on page 4. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 4
# DEBUG: Finalized topic starting on page 4
# DEBUG: Found START marker 'Typical Issues' on page 5. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 5
# DEBUG: Finalized topic starting on page 5
# DEBUG: Found START marker 'Typical Issues' on page 6. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 6
# DEBUG: Skipping intermediate heading 'Examples' on page 6
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 7
# DEBUG: Skipping intermediate heading 'Examples' on page 7
# DEBUG: Finalized topic starting on page 6
# DEBUG: Found START marker 'Typical Issues' on page 8. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 8
# DEBUG: Finalized topic starting on page 8
# DEBUG: Found START marker 'Typical Issues' on page 9. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 9
# DEBUG: Skipping intermediate heading 'Examples' on page 9
# DEBUG: Finalized topic starting on page 9
# DEBUG: Found START marker 'Typical Issues' on page 10. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 10
# DEBUG: Skipping intermediate heading 'Examples' on page 10
# DEBUG: Finalized topic starting on page 10
# DEBUG: Found START marker 'Typical Issues' on page 11. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 11
# DEBUG: Skipping intermediate heading 'Examples' on page 11
# DEBUG: Finalized topic starting on page 11
# DEBUG: Found START marker 'Typical Issues' on page 12. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 12
# DEBUG: Skipping intermediate heading 'Examples' on page 12
# DEBUG: Finalized topic starting on page 12
# DEBUG: Found START marker 'Typical Issues' on page 13. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 13
# DEBUG: Skipping intermediate heading 'Examples' on page 13
# DEBUG: Finalized topic starting on page 13
# DEBUG: Found START marker 'Typical Issues' on page 14. Starting new topic.
# DEBUG: Finalized topic starting on page 14
# DEBUG: Found START marker 'Typical Issues' on page 15. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 15
# DEBUG: Skipping intermediate heading 'Examples' on page 15
# DEBUG: Finalized topic starting on page 15
# DEBUG: Found START marker 'Typical Issues' on page 16. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 16
# DEBUG: Skipping intermediate heading 'Examples' on page 16
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 17
# DEBUG: Skipping intermediate heading 'Examples' on page 17
# DEBUG: Skipping intermediate heading 'Examples' on page 18
# DEBUG: Finalized topic starting on page 16
# DEBUG: Found START marker 'Typical Issues' on page 19. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 19
# DEBUG: Skipping intermediate heading 'Examples' on page 19
# DEBUG: Finalized topic starting on page 19
# DEBUG: Found START marker 'Typical Issues' on page 20. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 20
# DEBUG: Skipping intermediate heading 'Examples' on page 20
# DEBUG: Finalized topic starting on page 20
# DEBUG: Found START marker 'Typical Issues' on page 21. Starting new topic.
# DEBUG: Finalized topic starting on page 21
# DEBUG: Found START marker 'Typical Issues' on page 22. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 22
# DEBUG: Skipping intermediate heading 'Examples' on page 22
# DEBUG: Finalized topic starting on page 22
# DEBUG: Found START marker 'Typical Issues' on page 23. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 23
# DEBUG: Skipping intermediate heading 'Examples' on page 23
# DEBUG: Finalized topic starting on page 23
# DEBUG: Found START marker 'Typical Issues' on page 24. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 24
# DEBUG: Skipping intermediate heading 'Examples' on page 24
# DEBUG: Finalized topic starting on page 24
# DEBUG: Found START marker 'Typical Issues' on page 25. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 25
# DEBUG: Skipping intermediate heading 'Examples' on page 25
# DEBUG: Finalized topic starting on page 25
# DEBUG: Found START marker 'Typical Issues' on page 26. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 26
# DEBUG: Skipping intermediate heading 'Examples' on page 26
# DEBUG: Finalized topic starting on page 26
# DEBUG: Found START marker 'Typical Issues' on page 27. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 27
# DEBUG: Finalized topic starting on page 27
# DEBUG: Found START marker 'Typical Issues' on page 28. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 28
# DEBUG: Finalized topic starting on page 28
# DEBUG: Found START marker 'Typical Issues' on page 29. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 29
# DEBUG: Skipping intermediate heading 'Examples' on page 29
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 30
# DEBUG: Skipping intermediate heading 'Examples' on page 30
# DEBUG: Finalized topic starting on page 29
# DEBUG: Found START marker 'Typical Issues' on page 31. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 31
# DEBUG: Skipping intermediate heading 'Examples' on page 31
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 33
# DEBUG: Skipping intermediate heading 'Examples' on page 33
# DEBUG: Finalized topic starting on page 31
# DEBUG: Found START marker 'Typical Issues' on page 34. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 34
# DEBUG: Skipping intermediate heading 'Examples' on page 34
# DEBUG: Finalized topic starting on page 34
# DEBUG: Found START marker 'Typical Issues' on page 35. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 35
# DEBUG: Skipping intermediate heading 'Examples' on page 35
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 36
# DEBUG: Skipping intermediate heading 'Examples' on page 36
# DEBUG: Finalized topic starting on page 35
# DEBUG: Found START marker 'Typical Issues' on page 37. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 37
# DEBUG: Skipping intermediate heading 'Examples' on page 37
# DEBUG: Finalized topic starting on page 37
# DEBUG: Found START marker 'Typical Issues' on page 38. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 38
# DEBUG: Skipping intermediate heading 'Examples' on page 38
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 39
# DEBUG: Finalized topic starting on page 38
# DEBUG: Found START marker 'Typical Issues' on page 40. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 40
# DEBUG: Skipping intermediate heading 'Examples' on page 40
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 41
# DEBUG: Finalized topic starting on page 40
# DEBUG: Found START marker 'Typical Issues' on page 42. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 42
# DEBUG: Skipping intermediate heading 'Examples' on page 42
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 43
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 44
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 45
# DEBUG: Skipping intermediate heading 'Examples' on page 45
# DEBUG: Finalized topic starting on page 42
# DEBUG: Found START marker 'Typical Issues' on page 46. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 46
# DEBUG: Skipping intermediate heading 'Examples' on page 46
# DEBUG: Finalized topic starting on page 46
# DEBUG: Found START marker 'Typical Issues' on page 47. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 47
# DEBUG: Finalized topic starting on page 47
# DEBUG: Found START marker 'Typical Issues' on page 48. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 48
# DEBUG: Finalized topic starting on page 48
# DEBUG: Found START marker 'Typical Issues' on page 49. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 49
# DEBUG: Skipping intermediate heading 'Examples' on page 49
# DEBUG: Finalized topic starting on page 49
# DEBUG: Found START marker 'Typical Issues' on page 50. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 50
# DEBUG: Finalized topic starting on page 50
# DEBUG: Found START marker 'Typical Issues' on page 52. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 52
# DEBUG: Finalized topic starting on page 52
# DEBUG: Found START marker 'Typical Issues' on page 55. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 55
# DEBUG: Skipping intermediate heading 'Examples' on page 55
# DEBUG: Finalized topic starting on page 55
# DEBUG: Found START marker 'Typical Issues' on page 57. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 57
# DEBUG: Skipping intermediate heading 'Examples' on page 57
# DEBUG: Finalized topic starting on page 57
# DEBUG: Found START marker 'Typical Issues' on page 58. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 58
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 59
# DEBUG: Skipping intermediate heading 'Examples' on page 59
# DEBUG: Finalized topic starting on page 58
# DEBUG: Found START marker 'Typical Issues' on page 60. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 60
# DEBUG: Skipping intermediate heading 'Examples' on page 60
# DEBUG: Finalized topic starting on page 60
# DEBUG: Found START marker 'Typical Issues' on page 61. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 61
# DEBUG: Skipping intermediate heading 'Examples' on page 61
# DEBUG: Finalized topic starting on page 61
# DEBUG: Found START marker 'Typical Issues' on page 62. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 62
# DEBUG: Finalized topic starting on page 62
# DEBUG: Found START marker 'Typical Issues' on page 63. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 63
# DEBUG: Skipping intermediate heading 'Examples' on page 63
# DEBUG: Finalized topic starting on page 63
# DEBUG: Found START marker 'Typical Issues' on page 64. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 64
# DEBUG: Skipping intermediate heading 'Examples' on page 64
# DEBUG: Finalized topic starting on page 64
# DEBUG: Found START marker 'Typical Issues' on page 65. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 65
# DEBUG: Finalized topic starting on page 65
# DEBUG: Found START marker 'Typical Issues' on page 67. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 67
# DEBUG: Skipping intermediate heading 'Examples' on page 67
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 68
# DEBUG: Finalized topic starting on page 67
# DEBUG: Found START marker 'Typical Issues' on page 69. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 69
# DEBUG: Skipping intermediate heading 'Examples' on page 69
# DEBUG: Finalized topic starting on page 69
# DEBUG: Found START marker 'Typical Issues' on page 70. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 70
# DEBUG: Skipping intermediate heading 'Examples' on page 70
# DEBUG: Finalized topic starting on page 70
# DEBUG: Found START marker 'Typical Issues' on page 72. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 72
# DEBUG: Skipping intermediate heading 'Examples' on page 72
# DEBUG: Finalized topic starting on page 72
# DEBUG: Found START marker 'Typical Issues' on page 73. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 73
# DEBUG: Skipping intermediate heading 'Examples' on page 73
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 74
# DEBUG: Skipping intermediate heading 'Examples' on page 74
# DEBUG: Finalized topic starting on page 73
# DEBUG: Found START marker 'Typical Issues' on page 75. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 75
# DEBUG: Skipping intermediate heading 'Examples' on page 75
# DEBUG: Finalized topic starting on page 75
# DEBUG: Found START marker 'Typical Issues' on page 76. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 76
# DEBUG: Skipping intermediate heading 'Examples' on page 76
# DEBUG: Finalized topic starting on page 76
# DEBUG: Found START marker 'Typical Issues' on page 78. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 78
# DEBUG: Skipping intermediate heading 'Examples' on page 78
# DEBUG: Finalized topic starting on page 78
# DEBUG: Found START marker 'Typical Issues' on page 79. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 79
# DEBUG: Skipping intermediate heading 'Examples' on page 79
# DEBUG: Finalized topic starting on page 79
# DEBUG: Found START marker 'Typical Issues' on page 80. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 80
# DEBUG: Skipping intermediate heading 'Examples' on page 80
# DEBUG: Finalized topic starting on page 80
# DEBUG: Found START marker 'Typical Issues' on page 81. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 81
# DEBUG: Finalized topic starting on page 81
# DEBUG: Found START marker 'Typical Issues' on page 82. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 82
# DEBUG: Skipping intermediate heading 'Examples' on page 82
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 83
# DEBUG: Skipping intermediate heading 'Examples' on page 83
# DEBUG: Finalized topic starting on page 82
# DEBUG: Found START marker 'Typical Issues' on page 85. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 85
# DEBUG: Skipping intermediate heading 'Examples' on page 85
# DEBUG: Finalized topic starting on page 85
# DEBUG: Found START marker 'Typical Issues' on page 86. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 86
# DEBUG: Skipping intermediate heading 'Examples' on page 86
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 87
# DEBUG: Skipping intermediate heading 'Examples' on page 87
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 88
# DEBUG: Finalized topic starting on page 86
# DEBUG: Found START marker 'Typical Issues' on page 89. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 89
# DEBUG: Skipping intermediate heading 'Examples' on page 89
# DEBUG: Finalized topic starting on page 89
# DEBUG: Found START marker 'Typical Issues' on page 90. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 90
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 91
# DEBUG: Finalized topic starting on page 90
# DEBUG: Found START marker 'Typical Issues' on page 93. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 93
# DEBUG: Finalized topic starting on page 93
# DEBUG: Found START marker 'Typical Issues' on page 95. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 95
# DEBUG: Skipping intermediate heading 'Examples' on page 95
# DEBUG: Finalized topic starting on page 95
# DEBUG: Found START marker 'Typical Issues' on page 96. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 96
# DEBUG: Finalized topic starting on page 96
# DEBUG: Found START marker 'Typical Issues' on page 97. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 97
# DEBUG: Skipping intermediate heading 'Examples' on page 97
# DEBUG: Skipping intermediate heading 'Examples' on page 98
# DEBUG: Finalized topic starting on page 97
# DEBUG: Found START marker 'Typical Issues' on page 100. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 100
# DEBUG: Finalized topic starting on page 100
# DEBUG: Found START marker 'Typical Issues' on page 101. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 101
# DEBUG: Skipping intermediate heading 'Examples' on page 101
# DEBUG: Finalized topic starting on page 101
# DEBUG: Found START marker 'Typical Issues' on page 102. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 102
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 103
# DEBUG: Finalized topic starting on page 102
# DEBUG: Found START marker 'Typical Issues' on page 104. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 104
# DEBUG: Skipping intermediate heading 'Examples' on page 106
# DEBUG: Finalized topic starting on page 104
# DEBUG: Found START marker 'Typical Issues' on page 107. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 107
# DEBUG: Finalized topic starting on page 107
# DEBUG: Found START marker 'Typical Issues' on page 108. Starting new topic.
# DEBUG: Finalized topic starting on page 108
# DEBUG: Found START marker 'Typical Issues' on page 110. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 110
# DEBUG: Skipping intermediate heading 'Examples' on page 110
# DEBUG: Finalized topic starting on page 110
# DEBUG: Found START marker 'Typical Issues' on page 111. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 111
# DEBUG: Skipping intermediate heading 'Examples' on page 111
# DEBUG: Finalized topic starting on page 111
# DEBUG: Found START marker 'Typical Issues' on page 112. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 112
# DEBUG: Finalized topic starting on page 112
# DEBUG: Found START marker 'Typical Issues' on page 113. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 113
# DEBUG: Skipping intermediate heading 'Examples' on page 113
# DEBUG: Finalized topic starting on page 113
# DEBUG: Found START marker 'Typical Issues' on page 114. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 114
# DEBUG: Finalized topic starting on page 114
# DEBUG: Found START marker 'Typical Issues' on page 116. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 116
# DEBUG: Skipping intermediate heading 'Examples' on page 116
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 117
# DEBUG: Skipping intermediate heading 'Examples' on page 118
# DEBUG: Finalized topic starting on page 116
# DEBUG: Found START marker 'Typical Issues' on page 119. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 119
# DEBUG: Finalized topic starting on page 119
# DEBUG: Found START marker 'Typical Issues' on page 120. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 120
# DEBUG: Finalized topic starting on page 120
# DEBUG: Found START marker 'Typical Issues' on page 121. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 121
# DEBUG: Skipping intermediate heading 'Examples' on page 121
# DEBUG: Finalized topic starting on page 121
# DEBUG: Found START marker 'Typical Issues' on page 122. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 122
# DEBUG: Skipping intermediate heading 'Examples' on page 122
# DEBUG: Finalized topic starting on page 122
# DEBUG: Found START marker 'Typical Issues' on page 123. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 123
# DEBUG: Skipping intermediate heading 'Examples' on page 123
# DEBUG: Finalized topic starting on page 123
# DEBUG: Found START marker 'Typical Issues' on page 124. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 124
# DEBUG: Finalized topic starting on page 124
# DEBUG: Found START marker 'Typical Issues' on page 125. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 125
# DEBUG: Finalized topic starting on page 125
# DEBUG: Found START marker 'Typical Issues' on page 126. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 126
# DEBUG: Finalized topic starting on page 126
# DEBUG: Found START marker 'Typical Issues' on page 127. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 127
# DEBUG: Finalized topic starting on page 127
# DEBUG: Found START marker 'Typical Issues' on page 128. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 128
# DEBUG: Skipping intermediate heading 'Examples' on page 128
# DEBUG: Finalized topic starting on page 128
# DEBUG: Found START marker 'Typical Issues' on page 129. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 129
# DEBUG: Skipping intermediate heading 'Examples' on page 129
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 130
# DEBUG: Skipping intermediate heading 'Examples' on page 130
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 131
# DEBUG: Finalized topic starting on page 129
# DEBUG: Found START marker 'Typical Issues' on page 132. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 132
# DEBUG: Finalized topic starting on page 132
# DEBUG: Found START marker 'Typical Issues' on page 133. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 133
# DEBUG: Skipping intermediate heading 'Examples' on page 133
# DEBUG: Finalized topic starting on page 133
# DEBUG: Found START marker 'Typical Issues' on page 134. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 134
# DEBUG: Skipping intermediate heading 'Examples' on page 134
# DEBUG: Finalized topic starting on page 134
# DEBUG: Found START marker 'Typical Issues' on page 135. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 135
# DEBUG: Skipping intermediate heading 'Examples' on page 135
# DEBUG: Finalized topic starting on page 135
# DEBUG: Found START marker 'Typical Issues' on page 136. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 136
# DEBUG: Skipping intermediate heading 'Examples' on page 136
# DEBUG: Finalized topic starting on page 136
# DEBUG: Found START marker 'Typical Issues' on page 137. Starting new topic.
# DEBUG: Finalized topic starting on page 137
# DEBUG: Found START marker 'Typical Issues' on page 139. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 139
# DEBUG: Skipping intermediate heading 'Examples' on page 139
# DEBUG: Finalized topic starting on page 139
# DEBUG: Found START marker 'Typical Issues' on page 140. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 140
# DEBUG: Skipping intermediate heading 'Examples' on page 141
# DEBUG: Finalized topic starting on page 140
# DEBUG: Found START marker 'Typical Issues' on page 142. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 142
# DEBUG: Skipping intermediate heading 'Examples' on page 142
# DEBUG: Finalized topic starting on page 142
# DEBUG: Found START marker 'Typical Issues' on page 143. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 143
# DEBUG: Skipping intermediate heading 'Examples' on page 143
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 144
# DEBUG: Skipping intermediate heading 'Examples' on page 144
# DEBUG: Finalized topic starting on page 143
# DEBUG: Found START marker 'Typical Issues' on page 145. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 145
# DEBUG: Skipping intermediate heading 'Examples' on page 145
# DEBUG: Finalized topic starting on page 145
# DEBUG: Found START marker 'Typical Issues' on page 146. Starting new topic.
# DEBUG: Finalized topic starting on page 146
# DEBUG: Found START marker 'Typical Issues' on page 147. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 147
# DEBUG: Skipping intermediate heading 'Examples' on page 147
# DEBUG: Finalized topic starting on page 147
# DEBUG: Found START marker 'Typical Issues' on page 148. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 148
# DEBUG: Finalized topic starting on page 148
# DEBUG: Found START marker 'Typical Issues' on page 150. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 150
# DEBUG: Skipping intermediate heading 'Examples' on page 150
# DEBUG: Finalized topic starting on page 150
# DEBUG: Found START marker 'Typical Issues' on page 151. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 151
# DEBUG: Skipping intermediate heading 'Examples' on page 152
# DEBUG: Finalized topic starting on page 151
# DEBUG: Found START marker 'Typical Issues' on page 154. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 154
# DEBUG: Skipping intermediate heading 'Examples' on page 154
# DEBUG: Finalized topic starting on page 154
# DEBUG: Found START marker 'Typical Issues' on page 155. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 155
# DEBUG: Skipping intermediate heading 'Examples' on page 155
# DEBUG: Finalized topic starting on page 155
# DEBUG: Found START marker 'Typical Issues' on page 156. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 156
# DEBUG: Skipping intermediate heading 'Examples' on page 156
# DEBUG: Finalized topic starting on page 156
# DEBUG: Found START marker 'Typical Issues' on page 157. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 157
# DEBUG: Skipping intermediate heading 'Examples' on page 157
# DEBUG: Finalized topic starting on page 157
# DEBUG: Found START marker 'Typical Issues' on page 158. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 158
# DEBUG: Skipping intermediate heading 'Examples' on page 158
# DEBUG: Finalized topic starting on page 158
# DEBUG: Found START marker 'Typical Issues' on page 159. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 159
# DEBUG: Skipping intermediate heading 'Examples' on page 159
# DEBUG: Finalized topic starting on page 159
# DEBUG: Found START marker 'Typical Issues' on page 160. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 160
# DEBUG: Skipping intermediate heading 'Examples' on page 160
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 161
# DEBUG: Finalized topic starting on page 160
# DEBUG: Found START marker 'Typical Issues' on page 162. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 162
# DEBUG: Finalized topic starting on page 162
# DEBUG: Found START marker 'Typical Issues' on page 163. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 163
# DEBUG: Skipping intermediate heading 'Examples' on page 163
# DEBUG: Finalized topic starting on page 163
# DEBUG: Found START marker 'Typical Issues' on page 164. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 164
# DEBUG: Skipping intermediate heading 'Examples' on page 164
# DEBUG: Finalized topic starting on page 164
# DEBUG: Found START marker 'Typical Issues' on page 165. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 165
# DEBUG: Finalized topic starting on page 165
# DEBUG: Found START marker 'Typical Issues' on page 166. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 166
# DEBUG: Finalized topic starting on page 166
# DEBUG: Found START marker 'Typical Issues' on page 167. Starting new topic.
# DEBUG: Finalized topic starting on page 167
# DEBUG: Found START marker 'Typical Issues' on page 168. Starting new topic.
# DEBUG: Finalized topic starting on page 168
# DEBUG: Found START marker 'Typical Issues' on page 169. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 169
# DEBUG: Skipping intermediate heading 'Examples' on page 169
# DEBUG: Finalized topic starting on page 169
# DEBUG: Found START marker 'Typical Issues' on page 170. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 170
# DEBUG: Skipping intermediate heading 'Examples' on page 170
# DEBUG: Finalized topic starting on page 170
# DEBUG: Found START marker 'Typical Issues' on page 171. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 171
# DEBUG: Finalized topic starting on page 171
# DEBUG: Found START marker 'Typical Issues' on page 173. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 173
# DEBUG: Skipping intermediate heading 'Examples' on page 173
# DEBUG: Finalized topic starting on page 173
# DEBUG: Found START marker 'Typical Issues' on page 174. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 174
# DEBUG: Skipping intermediate heading 'Examples' on page 174
# DEBUG: Finalized topic starting on page 174
# DEBUG: Found START marker 'Typical Issues' on page 175. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 175
# DEBUG: Skipping intermediate heading 'Examples' on page 175
# DEBUG: Finalized topic starting on page 175
# DEBUG: Found START marker 'Typical Issues' on page 176. Starting new topic.
# DEBUG: Finalized topic starting on page 176
# DEBUG: Found START marker 'Typical Issues' on page 177. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 177
# DEBUG: Skipping intermediate heading 'Examples' on page 177
# DEBUG: Finalized topic starting on page 177
# DEBUG: Found START marker 'Typical Issues' on page 178. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 178
# DEBUG: Finalized topic starting on page 178
# DEBUG: Found START marker 'Typical Issues' on page 179. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 179
# DEBUG: Skipping intermediate heading 'Examples' on page 179
# DEBUG: Finalized topic starting on page 179
# DEBUG: Found START marker 'Typical Issues' on page 180. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 180
# DEBUG: Skipping intermediate heading 'Examples' on page 180
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 181
# DEBUG: Skipping intermediate heading 'Examples' on page 181
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 182
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 183
# DEBUG: Skipping intermediate heading 'Examples' on page 183
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 184
# DEBUG: Finalized topic starting on page 180
# DEBUG: Found START marker 'Typical Issues' on page 185. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 185
# DEBUG: Finalized topic starting on page 185
# DEBUG: Found START marker 'Typical Issues' on page 186. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 186
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 187
# DEBUG: Finalized topic starting on page 186
# DEBUG: Found START marker 'Typical Issues' on page 188. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 188
# DEBUG: Finalized topic starting on page 188
# DEBUG: Found START marker 'Typical Issues' on page 189. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 189
# DEBUG: Finalized topic starting on page 189
# DEBUG: Found START marker 'Typical Issues' on page 190. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 190
# DEBUG: Finalized topic starting on page 190
# DEBUG: Found START marker 'Typical Issues' on page 191. Starting new topic.
# DEBUG: Finalized topic starting on page 191
# DEBUG: Found START marker 'Typical Issues' on page 193. Starting new topic.
# DEBUG: Finalized topic starting on page 193
# DEBUG: Found START marker 'Typical Issues' on page 195. Starting new topic.
# DEBUG: Finalized topic starting on page 195
# DEBUG: Found START marker 'Typical Issues' on page 196. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 196
# DEBUG: Skipping intermediate heading 'Examples' on page 196
# DEBUG: Finalized topic starting on page 196
# DEBUG: Found START marker 'Typical Issues' on page 198. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 198
# DEBUG: Skipping intermediate heading 'Examples' on page 198
# DEBUG: Finalized topic starting on page 198
# DEBUG: Found START marker 'Typical Issues' on page 199. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 199
# DEBUG: Finalized topic starting on page 199
# DEBUG: Found START marker 'Typical Issues' on page 200. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 200
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 201
# DEBUG: Finalized topic starting on page 200
# DEBUG: Found START marker 'Typical Issues' on page 202. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 206
# DEBUG: Finalized topic starting on page 202
# DEBUG: Found START marker 'Typical Issues' on page 207. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 207
# DEBUG: Skipping intermediate heading 'Examples' on page 207
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 208
# DEBUG: Skipping intermediate heading 'Examples' on page 208
# DEBUG: Finalized topic starting on page 207
# DEBUG: Found START marker 'Typical Issues' on page 209. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 209
# DEBUG: Finalized topic starting on page 209
# DEBUG: Found START marker 'Typical Issues' on page 210. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 210
# DEBUG: Finalized topic starting on page 210
# DEBUG: Found START marker 'Typical Issues' on page 211. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 211
# DEBUG: Finalized topic starting on page 211
# DEBUG: Found START marker 'Typical Issues' on page 212. Starting new topic.
# DEBUG: Skipping intermediate heading 'Examples' on page 212
# DEBUG: Finalized topic starting on page 212
# DEBUG: Found START marker 'Typical Issues' on page 213. Starting new topic.
# DEBUG: Finalized topic starting on page 213
# DEBUG: Found START marker 'Typical Issues' on page 214. Starting new topic.
# DEBUG: Skipping intermediate heading 'Typical Recommendations' on page 214
# DEBUG: Reached end of PDF while processing topic starting on page 214. Finalizing.
#
# Processing complete.
# Generated 151 grouped text chunk objects.
#
# --- Output ---
# Grouped text chunk data saved to: output_grouped_text_chunk/data/RCA_ABSgroup_grouped_text_chunks.json
#
# --- Note ---
# Each object in the JSON groups text from 'Typical Issues' until 'Primary Difficulty SOURCE'.
# Includes only 'source_document', 'start_page', and 'text_chunk' keys.
# This format is for specific structured viewing/processing.
